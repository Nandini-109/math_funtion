# %% [markdown]
# a=int(input("Enter a number :"))
# if a<0:
#     print(" The number is negative: ")
# else:
#     print(" The number is Positive")

# %%
a=int(input("Enter a number: "))
for i in range(1, a+1):
    if i % 2 == 0:
        print(f"{i} is Even " )
    else:
        print(f"{i} is Odd " )
# Out:
# Enter a number:  12
# 1 is Odd
# 2 is Even
# 3 is Odd
# 4 is Even
# 5 is Odd
# 6 is Even
# 7 is Odd
# 8 is Even
# 9 is Odd
# 10 is Even
# 11 is Odd
# 12 is Even

# %% [markdown]
#  ### MY FIRST PROGRAM

# %%
students=[" Nandini","Swati","Kajal","Mari","Tanu"]
students.append("Shreya")
print(students[0:3])
# Out:
# [' Nandini', 'Swati', 'Kajal']

# %%
for i in range(1,4):
    print("Reminder :",i)
# Out:
# Reminder : 1
# Reminder : 2
# Reminder : 3

# %%
i = 1
while i <= 3:
    print("Check Recharge:" , i)
    i+=1
# Out:
# Check Recharge: 1
# Check Recharge: 2
# Check Recharge: 3

# %%
plans = ["\u20B950"]
print(plans)
# Out:
# ['₹50']

# %%
plans =["\u20B999","\u20B9199","\u20B9399"]
print(plans[0])
plans.append("\u20B9599")
plans.append("\u20B9342")
plans.remove("\u20B9199")

print(plans)
# Out:
# ₹99
# ['₹99', '₹399', '₹599', '₹342']

# %%
def greet(user):
    print("Hello",user)
for i in range(3):
    greet("Anita")
# Out:
# Hello Anita
# Hello Anita
# Hello Anita

# %%
def greet():
    name=input("Enter your name :")
    print("Hello" , name)

n = int(input("Enter the range :" ))
for i in range(n):
        greet()
# Out:
# Enter the range : 5
# Enter your name : NANDINI
# Hello NANDINI
# Enter your name : SWATI
# Hello SWATI
# Enter your name : KAJAL
# Hello KAJAL
# Enter your name : TANU
# Hello TANU
# Enter your name : Maya
# Hello Maya
